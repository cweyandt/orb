# %%
from google.colab import drive
import pandas as pd
import numpy as np
import os
import re

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)
# Mount google drive to list the raw data files

# Mounting the drive is straightforward but requires authentication each 
# time we reset the session
drive.mount('/content/drive')
drive_path = '/content/drive/Shareddrives/Capstone_Vacancy/data/'
# ! ls /content/drive/Shareddrives/Capstone_Vacancy/data

fumehoodFlow = pd.read_pickle(drive_path + 'cleaned/' + 'fumehoodFlow.pkl')

fumehoodFlow.tail()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Floor                         2                  1         ...   2   1   2       1
# Room                        225          244   145    125  ... 225 145 244 245 145
# Fumehood                     81    80     93    68     56  ...  81  68  93  94  67
# ts                                                         ...
# 2021-05-07 20:10:00+00:00  85.0  91.0  247.0  82.0  553.0  ... NaN NaN NaN NaN NaN
# 2021-05-07 20:20:00+00:00   NaN  86.0    NaN  79.0  561.0  ... NaN NaN NaN NaN NaN
# 2021-05-07 20:30:00+00:00   NaN   NaN    NaN   NaN    NaN  ... NaN NaN NaN NaN NaN
# 2021-05-07 20:40:00+00:00   NaN   NaN    NaN   NaN    NaN  ... NaN NaN NaN NaN NaN
# 2021-05-07 20:50:00+00:00   NaN   NaN    NaN   NaN    NaN  ... NaN NaN NaN NaN NaN
#
# [5 rows x 27 columns]

# %%
fumehoodFlow['2021-03'].groupby("Room", axis=1).sum().diff().plot()

# %%
fumehoodFlow['2021-03'].groupby("Room", axis=1).sum().plot()

# %%
fumehoodFlow['2021-03'].groupby("Floor", axis=1).sum().plot()

# %%
fumehoodFlow['2021-03'].groupby("Floor", axis=1).sum().diff().plot()

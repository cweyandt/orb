# %%
from google.colab import drive
import pandas as pd
import numpy as np
import os
import re

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)
# Mount google drive to list the raw data files

# Mounting the drive is straightforward but requires authentication each 
# time we reset the session
drive.mount('/content/drive')
drive_path = '/content/drive/Shareddrives/Capstone_Vacancy/data/'
# ! ls /content/drive/Shareddrives/Capstone_Vacancy/data

waterMeter = pd.read_pickle(drive_path + 'cleaned/' + 'waterMeter.pkl').clip(lower=0, upper=20)

waterMeter.tail()
# Out:
# Mounted at /content/drive
#                            Flow
# ts
# 2021-05-07 10:20:00-07:00   0.0
# 2021-05-07 10:25:00-07:00   0.0
# 2021-05-07 10:30:00-07:00   0.0
# 2021-05-07 10:35:00-07:00   0.0
# 2021-05-07 10:40:00-07:00   0.0

# %%
waterMeter.plot()

# %%
waterMeter['2021-01-14'].plot()
plt.title('Laura Added a Title to this Plot')
# Out:
# Text(0.5, 1.0, 'Laura Added a Title to this Plot')
